# %% [markdown]
# # Here we are predicting using Regression  models from Fingure print

# %% [markdown]
# ## Installation

# %%
# Install RDKit.
# %%capture
# !pip install rdkit-pypi

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2021-12-10 13:41:37--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2021-12-10 13:41:37--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip.4’
#
# padel.zip.4         100%[===================>]  24.57M  --.-KB/s    in 0.1s
#
# 2021-12-10 13:41:37 (179 MB/s) - ‘padel.zip.4’ saved [25768637/25768637]
#
# --2021-12-10 13:41:37--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh [following]
# --2021-12-10 13:41:37--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231 [text/plain]
# Saving to: ‘padel.sh.4’
#
# padel.sh.4          100%[===================>]     231  --.-KB/s    in 0s
#
# 2021-12-10 13:41:37 (7.76 MB/s) - ‘padel.sh.4’ saved [231/231]

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.7/dist-packages (0.10.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (2.23.0)
# Requirement already satisfied: easydict in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: requests-cache~=0.7.0 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (0.7.5)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Collecting pyyaml>=5.4
#   Using cached PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
# Requirement already satisfied: attrs<22.0,>=21.2 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.2.0)
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)
# Installing collected packages: pyyaml
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 5.3.1
#     Uninstalling PyYAML-5.3.1:
#       Successfully uninstalled PyYAML-5.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lazypredict 0.2.9 requires PyYAML==5.3.1, but you have pyyaml 6.0 which is incompatible.
# Successfully installed pyyaml-6.0

# %%
# !pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.7/dist-packages (0.2.9)
# Requirement already satisfied: pandas==1.0.5 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.0.5)
# Requirement already satisfied: lightgbm==2.3.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (2.3.1)
# Requirement already satisfied: numpy==1.19.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.19.1)
# Requirement already satisfied: scipy==1.5.4 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.5.4)
# Requirement already satisfied: six==1.15.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.15.0)
# Requirement already satisfied: xgboost==1.1.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.1.1)
# Requirement already satisfied: tqdm==4.56.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (4.56.0)
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: scikit-learn==0.23.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (0.23.1)
# Requirement already satisfied: joblib==1.0.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.0.0)
# Requirement already satisfied: pytest==5.4.3 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (5.4.3)
# Collecting PyYAML==5.3.1
#   Using cached PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5->lazypredict) (2018.9)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (21.2.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (8.12.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (0.13.1)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (4.8.2)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (1.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (21.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (0.2.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.23.1->lazypredict) (3.0.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pytest==5.4.3->lazypredict) (3.0.6)
# Installing collected packages: PyYAML
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests-cache 0.7.5 requires pyyaml>=5.4, but you have pyyaml 5.3.1 which is incompatible.
# Successfully installed PyYAML-5.3.1

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np

from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

from sklearn.metrics import accuracy_score , confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import lazypredict
from lazypredict.Supervised import LazyRegressor
from chembl_webresource_client.new_client import new_client as n_c
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %% [markdown]
# **Kv1. 3 channel blockers have been found to alleviate disease symptoms in animal autoimmune diseases, chronic inflammatory diseases, and metabolic disease models without obvious side effects (Perez-Verdaguer et al., 2016).**

# %%
# Target search for KV1.3 Blockers
target = n_c.target
target_query = target.search('KCNA3') #KCNA3 is a gene
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  ... tax_id
# 0  [{'xref_id': 'P16390', 'xref_name': None, 'xre...  ...  10090
# 1  [{'xref_id': 'P22001', 'xref_name': None, 'xre...  ...   9606
# 2  [{'xref_id': 'P15384', 'xref_name': None, 'xre...  ...  10116
# 3                                                 []  ...   9606
#
# [4 rows x 9 columns]

# %% [markdown]
# # *Select and retrieve bioactivity data for Homo sapiens  (2nd entry)*

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL4633'

# %%
activity = n_c.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
# convert dictionary to pandas data frame
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#     activity_comment  activity_id  ... upper_value  value
# 0               None       239620  ...        None    9.7
# 1               None       241014  ...        None    8.0
# 2               None       242254  ...        None    3.7
# 3               None       243680  ...        None    3.2
# 4               None       243681  ...        None    3.9
# ..               ...          ...  ...         ...    ...
# 884             None     18519019  ...        None   30.0
# 885             None     18519020  ...        None   30.0
# 886             None     18519021  ...        None   30.0
# 887             None     18519022  ...        None  0.024
# 888             None     18519202  ...        None   30.0
#
# [889 rows x 45 columns]

# %%
#Saved the pd database as CSV format
df.to_csv('KV1.3_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# #2. Preprocess

# %% [markdown]
# ### a. Handle missing **values**
# *If* any compounds has missing value for the standard_value and canonical_smiles then that column is dropped .

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
#     activity_comment  activity_id  ... upper_value  value
# 0               None       239620  ...        None    9.7
# 1               None       241014  ...        None    8.0
# 2               None       242254  ...        None    3.7
# 3               None       243680  ...        None    3.2
# 4               None       243681  ...        None    3.9
# ..               ...          ...  ...         ...    ...
# 884             None     18519019  ...        None   30.0
# 885             None     18519020  ...        None   30.0
# 886             None     18519021  ...        None   30.0
# 887             None     18519022  ...        None  0.024
# 888             None     18519202  ...        None   30.0
#
# [887 rows x 45 columns]

# %% [markdown]
# *Here are we are considering Standard type = IC50 and the standard value means potency of the drug. Lower the number the better the potency of the drug becomes*
#
#
# >
#
#
#
#
# we can also say lower potency means we need lower concentration of the drug

# %%
# checking the unique smiles values
len(df2.canonical_smiles.unique())
# Out:
# 511

# %%
# dropping the duplicates
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#     activity_comment  activity_id  ... upper_value value
# 0               None       239620  ...        None   9.7
# 1               None       241014  ...        None   8.0
# 2               None       242254  ...        None   3.7
# 3               None       243680  ...        None   3.2
# 4               None       243681  ...        None   3.9
# ..               ...          ...  ...         ...   ...
# 883             None     18519018  ...        None  30.0
# 884             None     18519019  ...        None  30.0
# 885             None     18519020  ...        None  30.0
# 886             None     18519021  ...        None  30.0
# 888             None     18519202  ...        None  30.0
#
# [511 rows x 45 columns]

# %% [markdown]
# #Data pre-processing of the bioactivity data

# %% [markdown]
# *Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame*

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id  ... standard_value
# 0         CHEMBL421891  ...         9700.0
# 1         CHEMBL111539  ...         8000.0
# 2         CHEMBL109336  ...         3700.0
# 3         CHEMBL418444  ...         3200.0
# 4         CHEMBL109739  ...         3900.0
# ..                 ...  ...            ...
# 883      CHEMBL4208681  ...        30000.0
# 884      CHEMBL4207090  ...        30000.0
# 885      CHEMBL4218820  ...        30000.0
# 886      CHEMBL4211453  ...        30000.0
# 888      CHEMBL4215589  ...        30000.0
#
# [511 rows x 3 columns]

# %%
#Saves dataframe to CSV file
df3.to_csv('KV1.3_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# #Labeling compounds as either being active, inactive or intermediate

# %% [markdown]
# *The bioactivity data is in the IC50 unit. **Compounds having values of less than 1000 nM will be considered to be active** while those greater than 10,000 nM will be considered to be inactive. As for those values in between 1,000 and 10,000 nM will be referred to as intermediate*

# %%
df4 = pd.read_csv('KV1.3_02_bioactivity_data_preprocessed.csv')

# %% [markdown]
# ### Curation

# %%
# based on the above mention threshold labeling is done
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id  ...         class
# 0         CHEMBL421891  ...  intermediate
# 1         CHEMBL111539  ...  intermediate
# 2         CHEMBL109336  ...  intermediate
# 3         CHEMBL418444  ...  intermediate
# 4         CHEMBL109739  ...  intermediate
# ..                 ...  ...           ...
# 506      CHEMBL4208681  ...      inactive
# 507      CHEMBL4207090  ...      inactive
# 508      CHEMBL4218820  ...      inactive
# 509      CHEMBL4211453  ...      inactive
# 510      CHEMBL4215589  ...      inactive
#
# [511 rows x 4 columns]

# %%
#curated data is save as csv
df5.to_csv('KV1.3_03_bioactivity_data_curated.csv', index=False)

# %% [markdown]
# SAVING THE DATA on the local disc && ZIP the file

# %%
# ! zip KV1_3.zip *.csv

# %%
# ! ls -l

# %%
df_curated = pd.read_csv('KV1.3_03_bioactivity_data_curated.csv')
# df_curated = df5

# %%
df_curated_no_smiles = df_curated.drop(columns='canonical_smiles')

# %%
smiles = []

for i in df_curated.canonical_smiles.tolist():
  cpd = str(i).split('.')
  cpd_longest = max(cpd, key = len)
  smiles.append(cpd_longest)

smiles = pd.Series(smiles, name = 'canonical_smiles')

# %%
df_clean_smiles = pd.concat([df_curated_no_smiles,smiles], axis=1)
df_clean_smiles
# Out:
#     molecule_chembl_id  ...                                   canonical_smiles
# 0         CHEMBL421891  ...   CCCNC(=O)c1cc(/C=C/c2ccc(F)cc2)ccc1-c1ccc(Cl)cc1
# 1         CHEMBL111539  ...    CCCCNC(=O)c1cc(/C=C/c2ccccc2F)ccc1-c1ccc(Cl)cc1
# 2         CHEMBL109336  ...  CC(C)NC(=O)c1cc(/C=C/c2ccc(Cl)c(F)c2)ccc1-c1cc...
# 3         CHEMBL418444  ...     CCNC(=O)c1cc(/C=C/CCc2ccccc2)ccc1-c1ccc(Cl)cc1
# 4         CHEMBL109739  ...  N=C(N)NNC(=O)c1cc(/C=C/c2ccc(F)cc2)ccc1-c1ccc(...
# ..                 ...  ...                                                ...
# 506      CHEMBL4208681  ...                  Nc1nc(/C=C/CNC(=O)C2CCNCC2)c[nH]1
# 507      CHEMBL4207090  ...           Nc1nc(CCCNC(=O)c2cc(Br)c(Br)[nH]2)c[nH]1
# 508      CHEMBL4218820  ...             Nc1nc(CCCNC(=O)c2cc3ccccc3[nH]2)c[nH]1
# 509      CHEMBL4211453  ...                Nc1nc(CCCNC(=O)C2Cc3ccccc3N2)c[nH]1
# 510      CHEMBL4215589  ...      COc1ccc2[nH]c(C(=O)NC/C=C/c3c[nH]c(N)n3)cc2c1
#
# [511 rows x 4 columns]

# %% [markdown]
# # Calculate Lipinski descriptors

# %% [markdown]
# Christopher Lipinski, a scientist at Pfizer, came up with a set of rule-of-thumb for evaluating the druglikeness of compounds. Such druglikeness is based on the Absorption, Distribution, Metabolism and Excretion (ADME) that is also known as the pharmacokinetic profile. Lipinski analyzed all orally active FDA-approved drugs in the formulation of what is to be known as the Rule-of-Five or Lipinski's Rule.
#
# The Lipinski's Rule stated the following:
#
#
#
# *  Molecular weight < 500 Dalton
# *  Octanol-water partition coefficient (LogP) < 5
# *  Hydrogen bond donors < 5
# *  Hydrogen bond acceptors < 10
# >
# Inspired by: https://codeocean.com/explore/capsules?query=tag:data-curation

# %%
def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem) 
        moldata.append(mol)
       
    baseData= np.arange(1,1)
    i=0  
    for mol in moldata:        
       
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])   
    
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1      
    
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return descriptors

# %%
df_lipinski = lipinski(df_clean_smiles.canonical_smiles)
df_lipinski
# Out:
#         MW  LogP  NumHDonors  NumHAcceptors
# 0   393.89  6.46        1.00           1.00
# 1   407.92  6.85        1.00           1.00
# 2   428.33  7.11        1.00           1.00
# 3   389.93  6.40        1.00           1.00
# 4   408.86  4.44        4.00           2.00
# ..     ...   ...         ...            ...
# 506 249.32  0.12        4.00           4.00
# 507 391.07  2.21        4.00           3.00
# 508 283.33  1.84        4.00           3.00
# 509 285.35  1.08        4.00           4.00
# 510 311.35  1.92        4.00           4.00
#
# [511 rows x 4 columns]

# %%
df_combined = pd.concat([df_curated,df_lipinski], axis=1)

# %%
df_combined
# Out:
#     molecule_chembl_id  ... NumHAcceptors
# 0         CHEMBL421891  ...          1.00
# 1         CHEMBL111539  ...          1.00
# 2         CHEMBL109336  ...          1.00
# 3         CHEMBL418444  ...          1.00
# 4         CHEMBL109739  ...          2.00
# ..                 ...  ...           ...
# 506      CHEMBL4208681  ...          4.00
# 507      CHEMBL4207090  ...          3.00
# 508      CHEMBL4218820  ...          3.00
# 509      CHEMBL4211453  ...          4.00
# 510      CHEMBL4215589  ...          4.00
#
# [511 rows x 8 columns]

# %% [markdown]
# Convert IC50 to pIC50 To allow IC50 data to be more uniformly distributed, we will convert IC50 to the negative logarithmic scale which is essentially -log10(IC50).
# >
# This custom function pIC50() will accept a DataFrame as input and will:
# >
# Take the IC50 values from the standard_value column and converts it from nM to M by multiplying the value by 10 −9  Take the molar value and apply -log10 Delete the standard_value column and create a new pIC50 column

# %%
def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm', 1)
        
    return x

# %% [markdown]
# Point to note: Values greater than 100,000,000 will be fixed at 100,000,000 otherwise the negative logarithmic value will become negative.

# %%
df_combined.standard_value.describe()
# Out:
# count      511.00
# mean      6045.76
# std      17502.41
# min          0.03
# 25%          3.33
# 50%        270.00
# 75%       2770.00
# max     230000.00
# Name: standard_value, dtype: float64

# %%
# Normalize the value
def norm_value(input):
    norm = []

    for i in input['standard_value']:
        if i > 100000000:
          i = 100000000
        norm.append(i)

    input['standard_value_norm'] = norm
    x = input.drop('standard_value', 1)
        
    return x

# %% [markdown]
# We will first apply the norm_value() function so that the values in the standard_value column is normalized.

# %%
df_norm = norm_value(df_combined)
df_norm
# Out:
#     molecule_chembl_id  ... standard_value_norm
# 0         CHEMBL421891  ...             9700.00
# 1         CHEMBL111539  ...             8000.00
# 2         CHEMBL109336  ...             3700.00
# 3         CHEMBL418444  ...             3200.00
# 4         CHEMBL109739  ...             3900.00
# ..                 ...  ...                 ...
# 506      CHEMBL4208681  ...            30000.00
# 507      CHEMBL4207090  ...            30000.00
# 508      CHEMBL4218820  ...            30000.00
# 509      CHEMBL4211453  ...            30000.00
# 510      CHEMBL4215589  ...            30000.00
#
# [511 rows x 8 columns]

# %%
df_norm.standard_value_norm.describe()
# Out:
# count      511.00
# mean      6045.76
# std      17502.41
# min          0.03
# 25%          3.33
# 50%        270.00
# 75%       2770.00
# max     230000.00
# Name: standard_value_norm, dtype: float64

# %%
df_final = pIC50(df_norm)
df_final
# Out:
#     molecule_chembl_id  ... pIC50
# 0         CHEMBL421891  ...  5.01
# 1         CHEMBL111539  ...  5.10
# 2         CHEMBL109336  ...  5.43
# 3         CHEMBL418444  ...  5.49
# 4         CHEMBL109739  ...  5.41
# ..                 ...  ...   ...
# 506      CHEMBL4208681  ...  4.52
# 507      CHEMBL4207090  ...  4.52
# 508      CHEMBL4218820  ...  4.52
# 509      CHEMBL4211453  ...  4.52
# 510      CHEMBL4215589  ...  4.52
#
# [511 rows x 8 columns]

# %%
df_final.pIC50.describe()
# Out:
# count   511.00
# mean      6.98
# std       1.85
# min       3.64
# 25%       5.56
# 50%       6.57
# 75%       8.48
# max      10.51
# Name: pIC50, dtype: float64

# %%
df_final.to_csv('KV1.3_04_bioactivity_data_3class_pIC50.csv')

# %% [markdown]
# Removing the 'intermediate' bioactivity class
# Here, we will be removing the intermediate class from our data set.

# %%
df_2class = df_final[df_final['class'] != 'intermediate']
df_2class
# Out:
#     molecule_chembl_id  ... pIC50
# 6         CHEMBL281622  ...  6.70
# 11        CHEMBL112852  ...  5.00
# 13        CHEMBL290227  ...  7.07
# 14         CHEMBL55142  ...  6.62
# 15         CHEMBL55091  ...  6.33
# ..                 ...  ...   ...
# 506      CHEMBL4208681  ...  4.52
# 507      CHEMBL4207090  ...  4.52
# 508      CHEMBL4218820  ...  4.52
# 509      CHEMBL4211453  ...  4.52
# 510      CHEMBL4215589  ...  4.52
#
# [412 rows x 8 columns]

# %% [markdown]
# # Exploratory Data Analysis (Chemical Space Analysis) via Lipinski descriptors Import library

# %% [markdown]
# **Frequency** plot of the 2 bioactivity classes

# %%
plt.figure(figsize=(5.5, 5.5))

sns.countplot(x='class', data=df_2class, edgecolor='black')

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')

plt.savefig('plot_bioactivity_class.pdf')

# %% [markdown]
# Scatter plot of MW versus LogP It can be seen that the 2 bioactivity classes are spanning similar chemical spaces as evident by the scatter plot of MW vs LogP.

# %%
plt.figure(figsize=(5.5, 5.5))

sns.scatterplot(x='MW', y='LogP', data=df_2class, hue='class', size='pIC50', edgecolor='black', alpha=0.7)

plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP.pdf')

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'pIC50', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('pIC50 value', fontsize=14, fontweight='bold')

plt.savefig('plot_ic50.pdf')

# %% [markdown]
# ## Statistical analysis | Mann-Whitney U Test

# %%
def mannwhitney(descriptor, verbose=False):
  # https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
  from numpy.random import seed
  from numpy.random import randn
  from scipy.stats import mannwhitneyu

# seed the random number generator
  seed(1)

# actives and inactives
  selection = [descriptor, 'class']
  df = df_2class[selection]
  active = df[df['class'] == 'active']
  active = active[descriptor]

  selection = [descriptor, 'class']
  df = df_2class[selection]
  inactive = df[df['class'] == 'inactive']
  inactive = inactive[descriptor]

# compare samples
  stat, p = mannwhitneyu(active, inactive)
  #print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
  alpha = 0.05
  if p > alpha:
    interpretation = 'Same distribution (fail to reject H0)'
  else:
    interpretation = 'Different distribution (reject H0)'
  
  results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
  filename = 'mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %%
mannwhitney('pIC50')
# Out:
#   Descriptor  Statistics    p  alpha                      Interpretation
# 0      pIC50        0.00 0.00   0.05  Different distribution (reject H0)

# %% [markdown]
# ## MW

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'MW', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=14, fontweight='bold')

plt.savefig('plot_MW.pdf')

# %%
mannwhitney('MW')
# Out:
#   Descriptor  Statistics    p  alpha                      Interpretation
# 0         MW     4180.00 0.00   0.05  Different distribution (reject H0)

# %% [markdown]
# ## LogP

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'LogP', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')

plt.savefig('plot_LogP.pdf')

# %% [markdown]
# Statistical analysis | Mann-Whitney U Test

# %%
mannwhitney('LogP')
# Out:
#   Descriptor  Statistics    p  alpha                      Interpretation
# 0       LogP    10665.50 0.04   0.05  Different distribution (reject H0)

# %% [markdown]
# ## NumHDonors

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'NumHDonors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHDonors.pdf')

# %%
mannwhitney('NumHDonors')
# Out:
#    Descriptor  Statistics    p  alpha                      Interpretation
# 0  NumHDonors     7925.50 0.00   0.05  Different distribution (reject H0)

# %% [markdown]
# ### NumHAcceptors

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'NumHAcceptors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHAcceptors.pdf')

# %%
mannwhitney('NumHAcceptors')
# Out:
#       Descriptor  Statistics    p  alpha                      Interpretation
# 0  NumHAcceptors     5183.00 0.00   0.05  Different distribution (reject H0)

# %% [markdown]
# # Interpretation of Statistical Results
# *Box* *Plots*
# *pIC50 values*
# Taking a look at pIC50 values, the actives and inactives displayed statistically significant difference, which is to be expected since ***threshold values (IC50 < 1,000 nM = Actives while IC50 > 10,000 nM = Inactives, corresponding to pIC50 > 6 = Actives and pIC50 < 5 = Inactives)*** were used to define actives and inactives.
#
# Lipinski's descriptors
# All of the 4 Lipinski's descriptors exhibited statistically significant difference between the actives and inactives.

# %%
# ! zip -r results.zip . -i *.csv *.pdf

# %% [markdown]
# ## Now  we will be calculating molecular descriptors that are essentially quantitative description of the compounds in the dataset.

# %%
# df3 = pd.read_csv('KV1.3_04_bioactivity_data_3class_pIC50.csv')
df3= df_final

# %%
df3
# Out:
#     molecule_chembl_id  ... pIC50
# 0         CHEMBL421891  ...  5.01
# 1         CHEMBL111539  ...  5.10
# 2         CHEMBL109336  ...  5.43
# 3         CHEMBL418444  ...  5.49
# 4         CHEMBL109739  ...  5.41
# ..                 ...  ...   ...
# 506      CHEMBL4208681  ...  4.52
# 507      CHEMBL4207090  ...  4.52
# 508      CHEMBL4218820  ...  4.52
# 509      CHEMBL4211453  ...  4.52
# 510      CHEMBL4215589  ...  4.52
#
# [511 rows x 8 columns]

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df3_selection = df3[selection]
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
! cat molecule.smi | head -5
# Out:
# CCCNC(=O)c1cc(/C=C/c2ccc(F)cc2)ccc1-c1ccc(Cl)cc1	CHEMBL421891
# CCCCNC(=O)c1cc(/C=C/c2ccccc2F)ccc1-c1ccc(Cl)cc1	CHEMBL111539
# CC(C)NC(=O)c1cc(/C=C/c2ccc(Cl)c(F)c2)ccc1-c1ccc(Cl)cc1	CHEMBL109336
# CCNC(=O)c1cc(/C=C/CCc2ccccc2)ccc1-c1ccc(Cl)cc1	CHEMBL418444
# N=C(N)NNC(=O)c1cc(/C=C/c2ccc(F)cc2)ccc1-c1ccc(Cl)cc1	CHEMBL109739

# %%
! cat molecule.smi | wc -l
# Out:
# 511

# %% [markdown]
# # Calculate fingerprint descriptors
#
# ## Calculate PaDEL descriptors

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2021-12-10 13:41:51--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2021-12-10 13:41:51--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip.5’
#
# padel.zip.5         100%[===================>]  24.57M  --.-KB/s    in 0.1s
#
# 2021-12-10 13:41:51 (174 MB/s) - ‘padel.zip.5’ saved [25768637/25768637]
#
# --2021-12-10 13:41:52--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh [following]
# --2021-12-10 13:41:52--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231 [text/plain]
# Saving to: ‘padel.sh.5’
#
# padel.sh.5          100%[===================>]     231  --.-KB/s    in 0s
#
# 2021-12-10 13:41:52 (10.1 MB/s) - ‘padel.sh.5’ saved [231/231]

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
# replace __MACOSX/._PaDEL-Descriptor? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh
# Out:
# Processing CHEMBL421891 in molecule.smi (1/511).
# Processing CHEMBL111539 in molecule.smi (2/511).
# Processing CHEMBL109336 in molecule.smi (3/511). Average speed: 10.63 s/mol.
# Processing CHEMBL418444 in molecule.smi (4/511). Average speed: 5.36 s/mol.
# Processing CHEMBL109739 in molecule.smi (5/511). Average speed: 3.93 s/mol.
# Processing CHEMBL109643 in molecule.smi (6/511). Average speed: 2.97 s/mol.
# Processing CHEMBL281622 in molecule.smi (7/511). Average speed: 2.56 s/mol.
# Processing CHEMBL111753 in molecule.smi (8/511). Average speed: 2.15 s/mol.
# Processing CHEMBL112516 in molecule.smi (9/511). Average speed: 1.91 s/mol.
# Processing CHEMBL325794 in molecule.smi (10/511). Average speed: 1.73 s/mol.
# Processing CHEMBL110004 in molecule.smi (11/511). Average speed: 1.61 s/mol.
# Processing CHEMBL112852 in molecule.smi (12/511). Average speed: 1.53 s/mol.
# Processing CHEMBL290227 in molecule.smi (14/511). Average speed: 1.34 s/mol.
# Processing CHEMBL109698 in molecule.smi (13/511). Average speed: 1.45 s/mol.
# Processing CHEMBL55142 in molecule.smi (15/511). Average speed: 1.39 s/mol.
# Processing CHEMBL56808 in molecule.smi (17/511). Average speed: 1.30 s/mol.
# Processing CHEMBL55091 in molecule.smi (16/511). Average speed: 1.27 s/mol.
# Processing CHEMBL59430 in molecule.smi (18/511). Average speed: 1.15 s/mol.
# Processing CHEMBL56124 in molecule.smi (19/511). Average speed: 1.17 s/mol.
# Processing CHEMBL55791 in molecule.smi (20/511). Average speed: 1.06 s/mol.
# Processing CHEMBL56173 in molecule.smi (21/511). Average speed: 1.02 s/mol.
# Processing CHEMBL294373 in molecule.smi (22/511). Average speed: 0.98 s/mol.
# Processing CHEMBL53676 in molecule.smi (23/511). Average speed: 0.94 s/mol.
# Processing CHEMBL299451 in molecule.smi (24/511). Average speed: 0.92 s/mol.
# Processing CHEMBL298622 in molecule.smi (25/511). Average speed: 0.88 s/mol.
# Processing CHEMBL56589 in molecule.smi (26/511). Average speed: 0.86 s/mol.
# Processing CHEMBL54934 in molecule.smi (27/511). Average speed: 0.83 s/mol.
# Processing CHEMBL53790 in molecule.smi (28/511). Average speed: 0.86 s/mol.
# Processing CHEMBL56998 in molecule.smi (29/511). Average speed: 0.79 s/mol.
# Processing CHEMBL291738 in molecule.smi (30/511). Average speed: 0.78 s/mol.
# Processing CHEMBL293719 in molecule.smi (31/511). Average speed: 0.76 s/mol.
# Processing CHEMBL299668 in molecule.smi (33/511). Average speed: 0.73 s/mol.
# Processing CHEMBL54231 in molecule.smi (32/511). Average speed: 0.74 s/mol.
# Processing CHEMBL56151 in molecule.smi (34/511). Average speed: 0.71 s/mol.
# Processing CHEMBL417417 in molecule.smi (35/511). Average speed: 0.70 s/mol.
# Processing CHEMBL56590 in molecule.smi (36/511). Average speed: 0.69 s/mol.
# Processing CHEMBL291674 in molecule.smi (37/511). Average speed: 0.68 s/mol.
# Processing CHEMBL53841 in molecule.smi (38/511). Average speed: 0.67 s/mol.
# Processing CHEMBL59482 in molecule.smi (39/511). Average speed: 0.65 s/mol.
# Processing CHEMBL59536 in molecule.smi (40/511). Average speed: 0.65 s/mol.
# Processing CHEMBL293083 in molecule.smi (41/511). Average speed: 0.64 s/mol.
# Processing CHEMBL298608 in molecule.smi (43/511). Average speed: 0.63 s/mol.
# Processing CHEMBL55202 in molecule.smi (42/511). Average speed: 0.63 s/mol.
# Processing CHEMBL416313 in molecule.smi (44/511). Average speed: 0.61 s/mol.
# Processing CHEMBL57615 in molecule.smi (45/511). Average speed: 0.60 s/mol.
# Processing CHEMBL293721 in molecule.smi (46/511). Average speed: 0.59 s/mol.
# Processing CHEMBL55649 in molecule.smi (47/511). Average speed: 0.58 s/mol.
# Processing CHEMBL59308 in molecule.smi (49/511). Average speed: 0.58 s/mol.
# Processing CHEMBL54846 in molecule.smi (48/511). Average speed: 0.58 s/mol.
# Processing CHEMBL57117 in molecule.smi (50/511). Average speed: 0.57 s/mol.
# Processing CHEMBL278971 in molecule.smi (52/511). Average speed: 0.56 s/mol.
# Processing CHEMBL56261 in molecule.smi (51/511). Average speed: 0.57 s/mol.
# Processing CHEMBL274227 in molecule.smi (53/511). Average speed: 0.57 s/mol.
# Processing CHEMBL279370 in molecule.smi (54/511). Average speed: 0.56 s/mol.
# Processing CHEMBL16308 in molecule.smi (55/511). Average speed: 0.55 s/mol.
# Processing CHEMBL278660 in molecule.smi (56/511). Average speed: 0.54 s/mol.
# Processing CHEMBL277598 in molecule.smi (57/511). Average speed: 0.54 s/mol.
# Processing CHEMBL275836 in molecule.smi (58/511). Average speed: 0.53 s/mol.
# Processing CHEMBL16806 in molecule.smi (59/511). Average speed: 0.53 s/mol.
# Processing CHEMBL16917 in molecule.smi (60/511). Average speed: 0.52 s/mol.
# Processing CHEMBL16792 in molecule.smi (61/511). Average speed: 0.52 s/mol.
# Processing CHEMBL279358 in molecule.smi (62/511). Average speed: 0.52 s/mol.
# Processing CHEMBL16449 in molecule.smi (63/511). Average speed: 0.52 s/mol.
# Processing CHEMBL16432 in molecule.smi (64/511). Average speed: 0.52 s/mol.
# Processing CHEMBL16848 in molecule.smi (66/511). Average speed: 0.51 s/mol.
# Processing CHEMBL16446 in molecule.smi (65/511). Average speed: 0.51 s/mol.
# Processing CHEMBL277952 in molecule.smi (67/511). Average speed: 0.51 s/mol.
# Processing CHEMBL17027 in molecule.smi (68/511). Average speed: 0.51 s/mol.
# Processing CHEMBL276543 in molecule.smi (69/511). Average speed: 0.51 s/mol.
# Processing CHEMBL280102 in molecule.smi (70/511). Average speed: 0.51 s/mol.
# Processing CHEMBL16706 in molecule.smi (72/511). Average speed: 0.50 s/mol.
# Processing CHEMBL278915 in molecule.smi (71/511). Average speed: 0.51 s/mol.
# Processing CHEMBL280052 in molecule.smi (73/511). Average speed: 0.50 s/mol.
# Processing CHEMBL16110 in molecule.smi (74/511). Average speed: 0.50 s/mol.
# Processing CHEMBL16450 in molecule.smi (75/511). Average speed: 0.50 s/mol.
# Processing CHEMBL16581 in molecule.smi (76/511). Average speed: 0.49 s/mol.
# Processing CHEMBL16804 in molecule.smi (77/511). Average speed: 0.49 s/mol.
# Processing CHEMBL429234 in molecule.smi (78/511). Average speed: 0.49 s/mol.
# Processing CHEMBL441507 in molecule.smi (79/511). Average speed: 0.49 s/mol.
# Processing CHEMBL16518 in molecule.smi (80/511). Average speed: 0.48 s/mol.
# Processing CHEMBL16945 in molecule.smi (81/511). Average speed: 0.48 s/mol.
# Processing CHEMBL277287 in molecule.smi (82/511). Average speed: 0.48 s/mol.
# Processing CHEMBL280079 in molecule.smi (83/511). Average speed: 0.48 s/mol.
# Processing CHEMBL16464 in molecule.smi (84/511). Average speed: 0.47 s/mol.
# Processing CHEMBL417995 in molecule.smi (85/511). Average speed: 0.47 s/mol.
# Processing CHEMBL277064 in molecule.smi (86/511). Average speed: 0.47 s/mol.
# Processing CHEMBL279529 in molecule.smi (87/511). Average speed: 0.47 s/mol.
# Processing CHEMBL277812 in molecule.smi (88/511). Average speed: 0.47 s/mol.
# Processing CHEMBL416538 in molecule.smi (89/511). Average speed: 0.46 s/mol.
# Processing CHEMBL16702 in molecule.smi (90/511). Average speed: 0.46 s/mol.
# Processing CHEMBL16877 in molecule.smi (91/511). Average speed: 0.46 s/mol.
# Processing CHEMBL16683 in molecule.smi (92/511). Average speed: 0.46 s/mol.
# Processing CHEMBL16652 in molecule.smi (93/511). Average speed: 0.46 s/mol.
# Processing CHEMBL16983 in molecule.smi (94/511). Average speed: 0.46 s/mol.
# Processing CHEMBL278269 in molecule.smi (95/511). Average speed: 0.46 s/mol.
# Processing CHEMBL16609 in molecule.smi (96/511). Average speed: 0.46 s/mol.
# Processing CHEMBL278945 in molecule.smi (97/511). Average speed: 0.45 s/mol.
# Processing CHEMBL16255 in molecule.smi (98/511). Average speed: 0.45 s/mol.
# Processing CHEMBL16890 in molecule.smi (99/511). Average speed: 0.45 s/mol.
# Processing CHEMBL16311 in molecule.smi (100/511). Average speed: 0.45 s/mol.
# Processing CHEMBL16381 in molecule.smi (102/511). Average speed: 0.45 s/mol.
# Processing CHEMBL279606 in molecule.smi (101/511). Average speed: 0.45 s/mol.
# Processing CHEMBL16746 in molecule.smi (104/511). Average speed: 0.44 s/mol.
# Processing CHEMBL276523 in molecule.smi (103/511). Average speed: 0.45 s/mol.
# Processing CHEMBL16844 in molecule.smi (105/511). Average speed: 0.44 s/mol.
# Processing CHEMBL16468 in molecule.smi (107/511). Average speed: 0.44 s/mol.
# Processing CHEMBL16512 in molecule.smi (106/511). Average speed: 0.44 s/mol.
# Processing CHEMBL279337 in molecule.smi (109/511). Average speed: 0.44 s/mol.
# Processing CHEMBL422393 in molecule.smi (108/511). Average speed: 0.44 s/mol.
# Processing CHEMBL275152 in molecule.smi (111/511). Average speed: 0.44 s/mol.
# Processing CHEMBL276059 in molecule.smi (110/511). Average speed: 0.44 s/mol.
# Processing CHEMBL274017 in molecule.smi (112/511). Average speed: 0.44 s/mol.
# Processing CHEMBL16882 in molecule.smi (113/511). Average speed: 0.43 s/mol.
# Processing CHEMBL273351 in molecule.smi (114/511). Average speed: 0.43 s/mol.
# Processing CHEMBL278734 in molecule.smi (115/511). Average speed: 0.43 s/mol.
# Processing CHEMBL265334 in molecule.smi (117/511). Average speed: 0.43 s/mol.
# Processing CHEMBL278501 in molecule.smi (116/511). Average speed: 0.43 s/mol.
# Processing CHEMBL16961 in molecule.smi (119/511). Average speed: 0.43 s/mol.
# Processing CHEMBL16766 in molecule.smi (118/511). Average speed: 0.43 s/mol.
# Processing CHEMBL276591 in molecule.smi (120/511). Average speed: 0.42 s/mol.
# Processing CHEMBL278213 in molecule.smi (121/511). Average speed: 0.42 s/mol.
# Processing CHEMBL16428 in molecule.smi (122/511). Average speed: 0.42 s/mol.
# Processing CHEMBL16287 in molecule.smi (123/511). Average speed: 0.42 s/mol.
# Processing CHEMBL16780 in molecule.smi (124/511). Average speed: 0.42 s/mol.
# Processing CHEMBL9653 in molecule.smi (125/511). Average speed: 0.42 s/mol.
# Processing CHEMBL148159 in molecule.smi (126/511). Average speed: 0.42 s/mol.
# Processing CHEMBL317791 in molecule.smi (127/511). Average speed: 0.42 s/mol.
# Processing CHEMBL362198 in molecule.smi (128/511). Average speed: 0.42 s/mol.
# Processing CHEMBL434526 in molecule.smi (129/511). Average speed: 0.42 s/mol.
# Processing CHEMBL362199 in molecule.smi (130/511). Average speed: 0.42 s/mol.
# Processing CHEMBL360583 in molecule.smi (131/511). Average speed: 0.43 s/mol.
# Processing CHEMBL361188 in molecule.smi (132/511). Average speed: 0.43 s/mol.
# Processing CHEMBL362068 in molecule.smi (133/511). Average speed: 0.43 s/mol.
# Processing CHEMBL368019 in molecule.smi (134/511). Average speed: 0.43 s/mol.
# Processing CHEMBL369340 in molecule.smi (136/511). Average speed: 0.43 s/mol.
# Processing CHEMBL368429 in molecule.smi (135/511). Average speed: 0.43 s/mol.
# Processing CHEMBL362445 in molecule.smi (138/511). Average speed: 0.44 s/mol.
# Processing CHEMBL366929 in molecule.smi (137/511). Average speed: 0.43 s/mol.
# Processing CHEMBL362446 in molecule.smi (139/511). Average speed: 0.44 s/mol.
# Processing CHEMBL359622 in molecule.smi (140/511). Average speed: 0.44 s/mol.
# Processing CHEMBL368907 in molecule.smi (141/511). Average speed: 0.44 s/mol.
# Processing CHEMBL178867 in molecule.smi (142/511). Average speed: 0.44 s/mol.
# Processing CHEMBL361777 in molecule.smi (144/511). Average speed: 0.44 s/mol.
# Processing CHEMBL359497 in molecule.smi (143/511). Average speed: 0.44 s/mol.
# Processing CHEMBL425156 in molecule.smi (145/511). Average speed: 0.45 s/mol.
# Processing CHEMBL435093 in molecule.smi (146/511). Average speed: 0.45 s/mol.
# Processing CHEMBL367603 in molecule.smi (148/511). Average speed: 0.45 s/mol.
# Processing CHEMBL425865 in molecule.smi (147/511). Average speed: 0.45 s/mol.
# Processing CHEMBL361828 in molecule.smi (149/511). Average speed: 0.45 s/mol.
# Processing CHEMBL362467 in molecule.smi (150/511). Average speed: 0.45 s/mol.
# Processing CHEMBL180972 in molecule.smi (151/511). Average speed: 0.45 s/mol.
# Processing CHEMBL182080 in molecule.smi (152/511). Average speed: 0.45 s/mol.
# Processing CHEMBL180665 in molecule.smi (153/511). Average speed: 0.45 s/mol.
# Processing CHEMBL178086 in molecule.smi (154/511). Average speed: 0.46 s/mol.
# Processing CHEMBL361810 in molecule.smi (155/511). Average speed: 0.46 s/mol.
# Processing CHEMBL178146 in molecule.smi (156/511). Average speed: 0.46 s/mol.
# Processing CHEMBL362608 in molecule.smi (157/511). Average speed: 0.46 s/mol.
# Processing CHEMBL360276 in molecule.smi (158/511). Average speed: 0.46 s/mol.
# Processing CHEMBL368435 in molecule.smi (159/511). Average speed: 0.46 s/mol.
# Processing CHEMBL176278 in molecule.smi (161/511). Average speed: 0.46 s/mol.
# Processing CHEMBL368210 in molecule.smi (160/511). Average speed: 0.47 s/mol.
# Processing CHEMBL366546 in molecule.smi (163/511). Average speed: 0.47 s/mol.
# Processing CHEMBL435336 in molecule.smi (162/511). Average speed: 0.47 s/mol.
# Processing CHEMBL359659 in molecule.smi (164/511). Average speed: 0.47 s/mol.
# Processing CHEMBL362825 in molecule.smi (165/511). Average speed: 0.47 s/mol.
# Processing CHEMBL360061 in molecule.smi (167/511). Average speed: 0.47 s/mol.
# Processing CHEMBL360060 in molecule.smi (166/511). Average speed: 0.47 s/mol.
# Processing CHEMBL497085 in molecule.smi (169/511). Average speed: 0.47 s/mol.
# Processing CHEMBL497084 in molecule.smi (168/511). Average speed: 0.48 s/mol.
# Processing CHEMBL522412 in molecule.smi (170/511). Average speed: 0.48 s/mol.
# Processing CHEMBL500166 in molecule.smi (172/511). Average speed: 0.47 s/mol.
# Processing CHEMBL502831 in molecule.smi (171/511). Average speed: 0.47 s/mol.
# Processing CHEMBL498728 in molecule.smi (173/511). Average speed: 0.47 s/mol.
# Processing CHEMBL496692 in molecule.smi (174/511). Average speed: 0.47 s/mol.
# Processing CHEMBL498086 in molecule.smi (175/511). Average speed: 0.47 s/mol.
# Processing CHEMBL498087 in molecule.smi (176/511). Average speed: 0.47 s/mol.
# Processing CHEMBL522750 in molecule.smi (177/511). Average speed: 0.47 s/mol.
# Processing CHEMBL496892 in molecule.smi (178/511). Average speed: 0.47 s/mol.
# Processing CHEMBL497249 in molecule.smi (179/511). Average speed: 0.46 s/mol.
# Processing CHEMBL522408 in molecule.smi (180/511). Average speed: 0.46 s/mol.
# Processing CHEMBL444449 in molecule.smi (182/511). Average speed: 0.46 s/mol.
# Processing CHEMBL497250 in molecule.smi (181/511). Average speed: 0.46 s/mol.
# Processing CHEMBL104 in molecule.smi (184/511). Average speed: 0.46 s/mol.
# Processing CHEMBL498270 in molecule.smi (183/511). Average speed: 0.46 s/mol.
# Processing CHEMBL524847 in molecule.smi (186/511). Average speed: 0.46 s/mol.
# Processing CHEMBL525412 in molecule.smi (185/511). Average speed: 0.46 s/mol.
# Processing CHEMBL498727 in molecule.smi (187/511). Average speed: 0.45 s/mol.
# Processing CHEMBL520173 in molecule.smi (188/511). Average speed: 0.45 s/mol.
# Processing CHEMBL515037 in molecule.smi (189/511). Average speed: 0.45 s/mol.
# Processing CHEMBL460814 in molecule.smi (190/511). Average speed: 0.45 s/mol.
# Processing CHEMBL516634 in molecule.smi (191/511). Average speed: 0.45 s/mol.
# Processing CHEMBL516932 in molecule.smi (192/511). Average speed: 0.45 s/mol.
# Processing CHEMBL24171 in molecule.smi (193/511). Average speed: 0.45 s/mol.
# Processing CHEMBL562547 in molecule.smi (194/511). Average speed: 0.45 s/mol.
# Processing CHEMBL539158 in molecule.smi (195/511). Average speed: 0.45 s/mol.
# Processing CHEMBL564031 in molecule.smi (196/511). Average speed: 0.45 s/mol.
# Processing CHEMBL549464 in molecule.smi (197/511). Average speed: 0.44 s/mol.
# Processing CHEMBL559624 in molecule.smi (199/511). Average speed: 0.44 s/mol.
# Processing CHEMBL552151 in molecule.smi (198/511). Average speed: 0.44 s/mol.
# Processing CHEMBL550822 in molecule.smi (201/511). Average speed: 0.44 s/mol.
# Processing CHEMBL540760 in molecule.smi (200/511). Average speed: 0.44 s/mol.
# Processing CHEMBL549316 in molecule.smi (203/511). Average speed: 0.44 s/mol.
# Processing CHEMBL550823 in molecule.smi (202/511). Average speed: 0.44 s/mol.
# Processing CHEMBL562876 in molecule.smi (204/511). Average speed: 0.44 s/mol.
# Processing CHEMBL549528 in molecule.smi (205/511). Average speed: 0.44 s/mol.
# Processing CHEMBL549529 in molecule.smi (207/511). Average speed: 0.43 s/mol.
# Processing CHEMBL559066 in molecule.smi (206/511). Average speed: 0.44 s/mol.
# Processing CHEMBL551028 in molecule.smi (209/511). Average speed: 0.43 s/mol.
# Processing CHEMBL562998 in molecule.smi (208/511). Average speed: 0.43 s/mol.
# Processing CHEMBL540174 in molecule.smi (210/511). Average speed: 0.43 s/mol.
# Processing CHEMBL559956 in molecule.smi (211/511). Average speed: 0.43 s/mol.
# Processing CHEMBL554144 in molecule.smi (212/511). Average speed: 0.43 s/mol.
# Processing CHEMBL559267 in molecule.smi (213/511). Average speed: 0.43 s/mol.
# Processing CHEMBL559268 in molecule.smi (214/511). Average speed: 0.43 s/mol.
# Processing CHEMBL550276 in molecule.smi (215/511). Average speed: 0.42 s/mol.
# Processing CHEMBL556250 in molecule.smi (216/511). Average speed: 0.42 s/mol.
# Processing CHEMBL541518 in molecule.smi (217/511). Average speed: 0.42 s/mol.
# Processing CHEMBL540249 in molecule.smi (218/511). Average speed: 0.42 s/mol.
# Processing CHEMBL569185 in molecule.smi (219/511). Average speed: 0.42 s/mol.
# Processing CHEMBL1289633 in molecule.smi (220/511). Average speed: 0.42 s/mol.
# Processing CHEMBL1287826 in molecule.smi (221/511). Average speed: 0.42 s/mol.
# Processing CHEMBL1289740 in molecule.smi (222/511). Average speed: 0.42 s/mol.
# Processing CHEMBL1289526 in molecule.smi (223/511). Average speed: 0.42 s/mol.
# Processing CHEMBL1290393 in molecule.smi (224/511). Average speed: 0.42 s/mol.
# Processing CHEMBL1289065 in molecule.smi (225/511). Average speed: 0.42 s/mol.
# Processing CHEMBL1289847 in molecule.smi (226/511). Average speed: 0.42 s/mol.
# Processing CHEMBL378104 in molecule.smi (227/511). Average speed: 0.41 s/mol.
# Processing CHEMBL1290277 in molecule.smi (228/511). Average speed: 0.41 s/mol.
# Processing CHEMBL1290616 in molecule.smi (230/511). Average speed: 0.41 s/mol.
# Processing CHEMBL1289634 in molecule.smi (229/511). Average speed: 0.41 s/mol.
# Processing CHEMBL1289965 in molecule.smi (231/511). Average speed: 0.41 s/mol.
# Processing CHEMBL1290394 in molecule.smi (233/511). Average speed: 0.41 s/mol.
# Processing CHEMBL1290614 in molecule.smi (232/511). Average speed: 0.41 s/mol.
# Processing CHEMBL1290506 in molecule.smi (234/511). Average speed: 0.41 s/mol.
# Processing CHEMBL1289296 in molecule.smi (235/511). Average speed: 0.41 s/mol.
# Processing CHEMBL1289739 in molecule.smi (236/511). Average speed: 0.41 s/mol.
# Processing CHEMBL1289964 in molecule.smi (237/511). Average speed: 0.41 s/mol.
# Processing CHEMBL1289184 in molecule.smi (238/511). Average speed: 0.41 s/mol.
# Processing CHEMBL1289295 in molecule.smi (239/511). Average speed: 0.41 s/mol.
# Processing CHEMBL1289183 in molecule.smi (240/511). Average speed: 0.41 s/mol.
# Processing CHEMBL1289411 in molecule.smi (241/511). Average speed: 0.40 s/mol.
# Processing CHEMBL1289846 in molecule.smi (242/511). Average speed: 0.40 s/mol.
# Processing CHEMBL1289182 in molecule.smi (243/511). Average speed: 0.40 s/mol.
# Processing CHEMBL1290734 in molecule.smi (244/511). Average speed: 0.40 s/mol.
# Processing CHEMBL1289412 in molecule.smi (245/511). Average speed: 0.40 s/mol.
# Processing CHEMBL1290167 in molecule.smi (246/511). Average speed: 0.40 s/mol.
# Processing CHEMBL1289066 in molecule.smi (248/511). Average speed: 0.40 s/mol.
# Processing CHEMBL1290168 in molecule.smi (247/511). Average speed: 0.40 s/mol.
# Processing CHEMBL1289527 in molecule.smi (249/511). Average speed: 0.40 s/mol.
# Processing CHEMBL1290505 in molecule.smi (252/511). Average speed: 0.40 s/mol.
# Processing CHEMBL1289067 in molecule.smi (250/511). Average speed: 0.40 s/mol.
# Processing CHEMBL1289185 in molecule.smi (251/511). Average speed: 0.40 s/mol.
# Processing CHEMBL1290615 in molecule.smi (254/511). Average speed: 0.40 s/mol.
# Processing CHEMBL1290061 in molecule.smi (253/511). Average speed: 0.40 s/mol.
# Processing CHEMBL1290736 in molecule.smi (255/511). Average speed: 0.40 s/mol.
# Processing CHEMBL1290062 in molecule.smi (256/511). Average speed: 0.39 s/mol.
# Processing CHEMBL1289064 in molecule.smi (257/511). Average speed: 0.39 s/mol.
# Processing CHEMBL1290278 in molecule.smi (258/511). Average speed: 0.39 s/mol.
# Processing CHEMBL1290617 in molecule.smi (259/511). Average speed: 0.40 s/mol.
# Processing CHEMBL1290735 in molecule.smi (260/511). Average speed: 0.39 s/mol.
# Processing CHEMBL1289297 in molecule.smi (261/511). Average speed: 0.39 s/mol.
# Processing CHEMBL1289848 in molecule.smi (262/511). Average speed: 0.39 s/mol.
# Processing CHEMBL1289636 in molecule.smi (263/511). Average speed: 0.39 s/mol.
# Processing CHEMBL1289529 in molecule.smi (265/511). Average speed: 0.39 s/mol.
# Processing CHEMBL1289637 in molecule.smi (264/511). Average speed: 0.39 s/mol.
# Processing CHEMBL1289635 in molecule.smi (266/511). Average speed: 0.39 s/mol.
# Processing CHEMBL1289413 in molecule.smi (267/511). Average speed: 0.39 s/mol.
# Processing CHEMBL1289528 in molecule.smi (269/511). Average speed: 0.39 s/mol.
# Processing CHEMBL1289741 in molecule.smi (268/511). Average speed: 0.39 s/mol.
# Processing CHEMBL1289414 in molecule.smi (271/511). Average speed: 0.39 s/mol.
# Processing CHEMBL1290733 in molecule.smi (270/511). Average speed: 0.39 s/mol.
# Processing CHEMBL1289966 in molecule.smi (273/511). Average speed: 0.39 s/mol.
# Processing CHEMBL1289415 in molecule.smi (272/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1289967 in molecule.smi (274/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1256851 in molecule.smi (275/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1289742 in molecule.smi (276/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1289849 in molecule.smi (277/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1289186 in molecule.smi (278/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1289530 in molecule.smi (279/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1289416 in molecule.smi (280/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1290737 in molecule.smi (281/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1290169 in molecule.smi (283/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1290510 in molecule.smi (282/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1289417 in molecule.smi (284/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1290509 in molecule.smi (285/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1289300 in molecule.smi (286/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1289188 in molecule.smi (287/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1289419 in molecule.smi (288/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1289068 in molecule.smi (289/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1289301 in molecule.smi (291/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1290618 in molecule.smi (290/511). Average speed: 0.38 s/mol.
# Processing CHEMBL1289969 in molecule.smi (292/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1290280 in molecule.smi (293/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1289299 in molecule.smi (294/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1289639 in molecule.smi (295/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1289744 in molecule.smi (296/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1289743 in molecule.smi (297/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1290170 in molecule.smi (298/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1289531 in molecule.smi (299/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1290279 in molecule.smi (300/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1289298 in molecule.smi (301/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1290621 in molecule.smi (303/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1290508 in molecule.smi (302/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1289070 in molecule.smi (304/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1290395 in molecule.smi (305/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1289850 in molecule.smi (306/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1290396 in molecule.smi (307/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1290507 in molecule.smi (308/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1290739 in molecule.smi (309/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1289069 in molecule.smi (310/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1289968 in molecule.smi (311/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1290063 in molecule.smi (312/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1290619 in molecule.smi (314/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1289071 in molecule.smi (313/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1290398 in molecule.smi (315/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1289851 in molecule.smi (316/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1289638 in molecule.smi (317/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1290064 in molecule.smi (318/511). Average speed: 0.37 s/mol.
# Processing CHEMBL1290738 in molecule.smi (319/511). Average speed: 0.36 s/mol.
# Processing CHEMBL1290171 in molecule.smi (321/511). Average speed: 0.36 s/mol.
# Processing CHEMBL1290172 in molecule.smi (320/511). Average speed: 0.36 s/mol.
# Processing CHEMBL1290282 in molecule.smi (323/511). Average speed: 0.36 s/mol.
# Processing CHEMBL1289418 in molecule.smi (322/511). Average speed: 0.36 s/mol.
# Processing CHEMBL1290740 in molecule.smi (324/511). Average speed: 0.36 s/mol.
# Processing CHEMBL1289187 in molecule.smi (325/511). Average speed: 0.36 s/mol.
# Processing CHEMBL1290281 in molecule.smi (326/511). Average speed: 0.36 s/mol.
# Processing CHEMBL1290397 in molecule.smi (327/511). Average speed: 0.36 s/mol.
# Processing CHEMBL1290620 in molecule.smi (328/511). Average speed: 0.36 s/mol.
# Processing CHEMBL1289189 in molecule.smi (329/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205337 in molecule.smi (331/511). Average speed: 0.36 s/mol.
# Processing CHEMBL6966 in molecule.smi (330/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205335 in molecule.smi (333/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205336 in molecule.smi (332/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205334 in molecule.smi (334/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205333 in molecule.smi (335/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205332 in molecule.smi (336/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205331 in molecule.smi (337/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205330 in molecule.smi (338/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205329 in molecule.smi (339/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205328 in molecule.smi (340/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205327 in molecule.smi (341/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205326 in molecule.smi (342/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205325 in molecule.smi (343/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205324 in molecule.smi (344/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205322 in molecule.smi (346/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205323 in molecule.smi (345/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205321 in molecule.smi (347/511). Average speed: 0.36 s/mol.
# Processing CHEMBL2205320 in molecule.smi (348/511). Average speed: 0.36 s/mol.
# Processing CHEMBL1201294 in molecule.smi (349/511). Average speed: 0.36 s/mol.
# Processing CHEMBL3609073 in molecule.smi (351/511). Average speed: 0.36 s/mol.
# Processing CHEMBL3609074 in molecule.smi (350/511). Average speed: 0.36 s/mol.
# Processing CHEMBL3609072 in molecule.smi (352/511). Average speed: 0.38 s/mol.
# Processing CHEMBL3609071 in molecule.smi (353/511). Average speed: 0.38 s/mol.
# Processing CHEMBL3609070 in molecule.smi (354/511). Average speed: 0.40 s/mol.
# Processing CHEMBL3609069 in molecule.smi (355/511). Average speed: 0.41 s/mol.
# Processing CHEMBL3609068 in molecule.smi (356/511). Average speed: 0.43 s/mol.
# Processing CHEMBL3609067 in molecule.smi (357/511). Average speed: 0.44 s/mol.
# Processing CHEMBL3609066 in molecule.smi (358/511). Average speed: 0.45 s/mol.
# Processing CHEMBL3609065 in molecule.smi (359/511). Average speed: 0.46 s/mol.
# Processing CHEMBL3609064 in molecule.smi (360/511). Average speed: 0.48 s/mol.
# Processing CHEMBL3609063 in molecule.smi (361/511). Average speed: 0.48 s/mol.
# Processing CHEMBL3609054 in molecule.smi (362/511). Average speed: 0.50 s/mol.
# Processing CHEMBL3609062 in molecule.smi (363/511). Average speed: 0.51 s/mol.
# Processing CHEMBL3609061 in molecule.smi (364/511). Average speed: 0.52 s/mol.
# Processing CHEMBL3609060 in molecule.smi (365/511). Average speed: 0.53 s/mol.
# Processing CHEMBL3609059 in molecule.smi (366/511). Average speed: 0.55 s/mol.
# Processing CHEMBL3609058 in molecule.smi (367/511). Average speed: 0.55 s/mol.
# Processing CHEMBL3609057 in molecule.smi (368/511). Average speed: 0.57 s/mol.
# Processing CHEMBL3609056 in molecule.smi (369/511). Average speed: 0.57 s/mol.
# Processing CHEMBL3609055 in molecule.smi (370/511). Average speed: 0.59 s/mol.
# Processing CHEMBL3609053 in molecule.smi (371/511). Average speed: 0.60 s/mol.
# Processing CHEMBL3609052 in molecule.smi (372/511). Average speed: 0.61 s/mol.
# Processing CHEMBL3609051 in molecule.smi (373/511). Average speed: 0.62 s/mol.
# Processing CHEMBL3609050 in molecule.smi (374/511). Average speed: 0.63 s/mol.
# Processing CHEMBL3609049 in molecule.smi (375/511). Average speed: 0.64 s/mol.
# Processing CHEMBL3609048 in molecule.smi (376/511). Average speed: 0.65 s/mol.
# Processing CHEMBL3609047 in molecule.smi (377/511). Average speed: 0.66 s/mol.
# Processing CHEMBL3609046 in molecule.smi (378/511). Average speed: 0.67 s/mol.
# Processing CHEMBL3609045 in molecule.smi (379/511). Average speed: 0.68 s/mol.
# Processing CHEMBL3609044 in molecule.smi (380/511). Average speed: 0.69 s/mol.
# Processing CHEMBL3609043 in molecule.smi (381/511). Average speed: 0.70 s/mol.
# Processing CHEMBL3609042 in molecule.smi (382/511). Average speed: 0.71 s/mol.
# Processing CHEMBL3609041 in molecule.smi (383/511). Average speed: 0.72 s/mol.
# Processing CHEMBL3608317 in molecule.smi (384/511). Average speed: 0.73 s/mol.
# Processing CHEMBL3609040 in molecule.smi (385/511). Average speed: 0.74 s/mol.
# Processing CHEMBL3609039 in molecule.smi (386/511). Average speed: 0.75 s/mol.
# Processing CHEMBL3609038 in molecule.smi (387/511). Average speed: 0.76 s/mol.
# Processing CHEMBL3609037 in molecule.smi (388/511). Average speed: 0.77 s/mol.
# Processing CHEMBL3609036 in molecule.smi (389/511). Average speed: 0.78 s/mol.
# Processing CHEMBL3609035 in molecule.smi (390/511). Average speed: 0.79 s/mol.
# Processing CHEMBL3609034 in molecule.smi (391/511). Average speed: 0.80 s/mol.
# Processing CHEMBL3609033 in molecule.smi (392/511). Average speed: 0.81 s/mol.
# Processing CHEMBL3609032 in molecule.smi (393/511). Average speed: 0.82 s/mol.
# Processing CHEMBL3609031 in molecule.smi (394/511). Average speed: 0.83 s/mol.
# Processing CHEMBL3609030 in molecule.smi (395/511). Average speed: 0.84 s/mol.
# Processing CHEMBL3609029 in molecule.smi (396/511). Average speed: 0.85 s/mol.
# Processing CHEMBL3609028 in molecule.smi (397/511). Average speed: 0.86 s/mol.
# Processing CHEMBL3609027 in molecule.smi (398/511). Average speed: 0.86 s/mol.
# Processing CHEMBL3609026 in molecule.smi (399/511). Average speed: 0.88 s/mol.
# Processing CHEMBL3609025 in molecule.smi (400/511). Average speed: 0.88 s/mol.
# Processing CHEMBL3609024 in molecule.smi (401/511). Average speed: 0.90 s/mol.
# Processing CHEMBL3609023 in molecule.smi (402/511). Average speed: 0.90 s/mol.
# Processing CHEMBL3609276 in molecule.smi (403/511). Average speed: 0.92 s/mol.
# Processing CHEMBL3609275 in molecule.smi (404/511). Average speed: 0.92 s/mol.
# Processing CHEMBL3609277 in molecule.smi (405/511). Average speed: 0.93 s/mol.
# Processing CHEMBL3609022 in molecule.smi (406/511). Average speed: 0.93 s/mol.
# Processing CHEMBL3609274 in molecule.smi (407/511). Average speed: 0.95 s/mol.
# Processing CHEMBL3609273 in molecule.smi (408/511). Average speed: 0.96 s/mol.
# Processing CHEMBL3609272 in molecule.smi (409/511). Average speed: 0.97 s/mol.
# Processing CHEMBL3609271 in molecule.smi (410/511). Average speed: 0.97 s/mol.
# Processing CHEMBL3609270 in molecule.smi (411/511). Average speed: 0.99 s/mol.
# Processing CHEMBL3609269 in molecule.smi (412/511). Average speed: 0.99 s/mol.
# Processing CHEMBL3609268 in molecule.smi (413/511). Average speed: 1.00 s/mol.
# Processing CHEMBL3609267 in molecule.smi (414/511). Average speed: 1.01 s/mol.
# Processing CHEMBL3609266 in molecule.smi (415/511). Average speed: 1.02 s/mol.
# Processing CHEMBL3609265 in molecule.smi (416/511). Average speed: 1.03 s/mol.
# Processing CHEMBL3609264 in molecule.smi (417/511). Average speed: 1.04 s/mol.
# Processing CHEMBL3609263 in molecule.smi (418/511). Average speed: 1.04 s/mol.
# Processing CHEMBL3609262 in molecule.smi (419/511). Average speed: 1.05 s/mol.
# Processing CHEMBL3609261 in molecule.smi (420/511). Average speed: 1.07 s/mol.
# Processing CHEMBL3609260 in molecule.smi (421/511). Average speed: 1.07 s/mol.
# Processing CHEMBL3609259 in molecule.smi (422/511). Average speed: 1.09 s/mol.
# Processing CHEMBL3609258 in molecule.smi (423/511). Average speed: 1.10 s/mol.
# Processing CHEMBL3609257 in molecule.smi (424/511). Average speed: 1.11 s/mol.
# Processing CHEMBL3609256 in molecule.smi (425/511). Average speed: 1.11 s/mol.
# Processing CHEMBL3609255 in molecule.smi (426/511). Average speed: 1.13 s/mol.
# Processing CHEMBL3609254 in molecule.smi (427/511). Average speed: 1.13 s/mol.
# Processing CHEMBL3609253 in molecule.smi (428/511). Average speed: 1.15 s/mol.
# Processing CHEMBL3609252 in molecule.smi (429/511). Average speed: 1.15 s/mol.
# Processing CHEMBL3609251 in molecule.smi (430/511). Average speed: 1.17 s/mol.
# Processing CHEMBL3608991 in molecule.smi (431/511). Average speed: 1.17 s/mol.
# Processing CHEMBL3609250 in molecule.smi (432/511). Average speed: 1.19 s/mol.
# Processing CHEMBL3609249 in molecule.smi (433/511). Average speed: 1.19 s/mol.
# Processing CHEMBL3609248 in molecule.smi (434/511). Average speed: 1.20 s/mol.
# Processing CHEMBL3609247 in molecule.smi (435/511). Average speed: 1.21 s/mol.
# Processing CHEMBL3609246 in molecule.smi (436/511). Average speed: 1.23 s/mol.
# Processing CHEMBL3609245 in molecule.smi (437/511). Average speed: 1.23 s/mol.
# Processing CHEMBL3609244 in molecule.smi (438/511). Average speed: 1.25 s/mol.
# Processing CHEMBL3609243 in molecule.smi (439/511). Average speed: 1.25 s/mol.
# Processing CHEMBL3609242 in molecule.smi (440/511). Average speed: 1.27 s/mol.
# Processing CHEMBL3609241 in molecule.smi (441/511). Average speed: 1.27 s/mol.
# Processing CHEMBL3609240 in molecule.smi (442/511). Average speed: 1.29 s/mol.
# Processing CHEMBL3609239 in molecule.smi (443/511). Average speed: 1.29 s/mol.
# Processing CHEMBL3608318 in molecule.smi (444/511). Average speed: 1.31 s/mol.
# Processing CHEMBL3609238 in molecule.smi (445/511). Average speed: 1.31 s/mol.
# Processing CHEMBL3609237 in molecule.smi (446/511). Average speed: 1.32 s/mol.
# Processing CHEMBL3609236 in molecule.smi (447/511). Average speed: 1.32 s/mol.
# Processing CHEMBL3609234 in molecule.smi (449/511). Average speed: 1.34 s/mol.
# Processing CHEMBL3609235 in molecule.smi (448/511). Average speed: 1.34 s/mol.
# Processing CHEMBL3609233 in molecule.smi (450/511). Average speed: 1.35 s/mol.
# Processing CHEMBL3609232 in molecule.smi (451/511). Average speed: 1.35 s/mol.
# Processing CHEMBL3609231 in molecule.smi (452/511). Average speed: 1.37 s/mol.
# Processing CHEMBL3609230 in molecule.smi (453/511). Average speed: 1.37 s/mol.
# Processing CHEMBL3609229 in molecule.smi (454/511). Average speed: 1.38 s/mol.
# Processing CHEMBL3609228 in molecule.smi (455/511). Average speed: 1.40 s/mol.
# Processing CHEMBL3609227 in molecule.smi (456/511). Average speed: 1.40 s/mol.
# Processing CHEMBL3609226 in molecule.smi (457/511). Average speed: 1.41 s/mol.
# Processing CHEMBL3609225 in molecule.smi (458/511). Average speed: 1.41 s/mol.
# Processing CHEMBL3609224 in molecule.smi (459/511). Average speed: 1.43 s/mol.
# Processing CHEMBL3609223 in molecule.smi (460/511). Average speed: 1.42 s/mol.
# Processing CHEMBL3609222 in molecule.smi (461/511). Average speed: 1.44 s/mol.
# Processing CHEMBL3609221 in molecule.smi (462/511). Average speed: 1.44 s/mol.
# Processing CHEMBL3609220 in molecule.smi (463/511). Average speed: 1.45 s/mol.
# Processing CHEMBL3608999 in molecule.smi (464/511). Average speed: 1.45 s/mol.
# Processing CHEMBL3608998 in molecule.smi (465/511). Average speed: 1.46 s/mol.
# Processing CHEMBL3608997 in molecule.smi (466/511). Average speed: 1.46 s/mol.
# Processing CHEMBL3608996 in molecule.smi (467/511). Average speed: 1.47 s/mol.
# Processing CHEMBL3608995 in molecule.smi (468/511). Average speed: 1.48 s/mol.
# Processing CHEMBL3608994 in molecule.smi (469/511). Average speed: 1.49 s/mol.
# Processing CHEMBL3608993 in molecule.smi (470/511). Average speed: 1.49 s/mol.
# Processing CHEMBL3608992 in molecule.smi (471/511). Average speed: 1.50 s/mol.
# Processing CHEMBL3609075 in molecule.smi (472/511). Average speed: 1.50 s/mol.
# Processing CHEMBL3609076 in molecule.smi (473/511). Average speed: 1.51 s/mol.
# Processing CHEMBL3609077 in molecule.smi (474/511). Average speed: 1.52 s/mol.
# Processing CHEMBL3609078 in molecule.smi (475/511). Average speed: 1.52 s/mol.
# Processing CHEMBL3609079 in molecule.smi (476/511). Average speed: 1.53 s/mol.
# Processing CHEMBL3609080 in molecule.smi (477/511). Average speed: 1.54 s/mol.
# Processing CHEMBL3609081 in molecule.smi (478/511). Average speed: 1.54 s/mol.
# Processing CHEMBL3609082 in molecule.smi (479/511). Average speed: 1.55 s/mol.
# Processing CHEMBL3609083 in molecule.smi (480/511). Average speed: 1.56 s/mol.
# Processing CHEMBL3609084 in molecule.smi (481/511). Average speed: 1.56 s/mol.
# Processing CHEMBL3609085 in molecule.smi (482/511). Average speed: 1.57 s/mol.
# Processing CHEMBL3609086 in molecule.smi (483/511). Average speed: 1.57 s/mol.
# Processing CHEMBL3609087 in molecule.smi (484/511). Average speed: 1.59 s/mol.
# Processing CHEMBL3609089 in molecule.smi (486/511). Average speed: 1.60 s/mol.
# Processing CHEMBL3609088 in molecule.smi (485/511). Average speed: 1.60 s/mol.
# Processing CHEMBL3609090 in molecule.smi (487/511). Average speed: 1.62 s/mol.
# Processing CHEMBL3609091 in molecule.smi (488/511). Average speed: 1.61 s/mol.
# Processing CHEMBL3609093 in molecule.smi (490/511). Average speed: 1.63 s/mol.
# Processing CHEMBL3609092 in molecule.smi (489/511). Average speed: 1.63 s/mol.
# Processing CHEMBL3609094 in molecule.smi (491/511). Average speed: 1.64 s/mol.
# Processing CHEMBL3609095 in molecule.smi (492/511). Average speed: 1.64 s/mol.
# Processing CHEMBL3920884 in molecule.smi (493/511). Average speed: 1.65 s/mol.
# Processing CHEMBL465679 in molecule.smi (494/511). Average speed: 1.65 s/mol.
# Processing CHEMBL3621636 in molecule.smi (495/511). Average speed: 1.65 s/mol.
# Processing CHEMBL397591 in molecule.smi (496/511). Average speed: 1.65 s/mol.
# Processing CHEMBL4213446 in molecule.smi (497/511). Average speed: 1.64 s/mol.
# Processing CHEMBL4208517 in molecule.smi (498/511). Average speed: 1.64 s/mol.
# Processing CHEMBL4202870 in molecule.smi (499/511). Average speed: 1.64 s/mol.
# Processing CHEMBL4207745 in molecule.smi (500/511). Average speed: 1.64 s/mol.
# Processing CHEMBL3261430 in molecule.smi (501/511). Average speed: 1.63 s/mol.
# Processing CHEMBL3261431 in molecule.smi (502/511). Average speed: 1.63 s/mol.
# Processing CHEMBL4210636 in molecule.smi (503/511). Average speed: 1.63 s/mol.
# Processing CHEMBL4206278 in molecule.smi (504/511). Average speed: 1.62 s/mol.
# Processing CHEMBL4211159 in molecule.smi (505/511). Average speed: 1.62 s/mol.
# Processing CHEMBL4203801 in molecule.smi (506/511). Average speed: 1.62 s/mol.
# Processing CHEMBL4208681 in molecule.smi (507/511). Average speed: 1.61 s/mol.
# Processing CHEMBL4207090 in molecule.smi (508/511). Average speed: 1.61 s/mol.
# Processing CHEMBL4218820 in molecule.smi (509/511). Average speed: 1.61 s/mol.
# Processing CHEMBL4211453 in molecule.smi (510/511). Average speed: 1.61 s/mol.
# Processing CHEMBL4215589 in molecule.smi (511/511). Average speed: 1.60 s/mol.
# Descriptor calculation completed in 13 mins 38.382 secs . Average speed: 1.60 s/mol.

# %%
! ls -l
# Out:
# total 154604
# -rw-r--r-- 1 root root   919613 Dec 10 14:10 descriptors_output.csv
# -rw-r--r-- 1 root root   785361 Dec 10 13:41 KV1.3_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root   128331 Dec 10 13:41 KV1.3_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root   132888 Dec 10 13:41 KV1.3_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root   163201 Dec 10 13:41 KV1.3_04_bioactivity_data_3class_pIC50.csv
# -rw-r--r-- 1 root root   920671 Dec 10 12:41 KV1.3_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# -rw-r--r-- 1 root root    52797 Dec 10 12:28 KV1_3.zip
# drwxr-xr-x 3 root root     4096 Dec 10 12:29 __MACOSX
# -rw-r--r-- 1 root root      121 Dec 10 13:41 mannwhitneyu_LogP.csv
# -rw-r--r-- 1 root root      120 Dec 10 13:41 mannwhitneyu_MW.csv
# -rw-r--r-- 1 root root      132 Dec 10 13:41 mannwhitneyu_NumHAcceptors.csv
# -rw-r--r-- 1 root root      128 Dec 10 13:41 mannwhitneyu_NumHDonors.csv
# -rw-r--r-- 1 root root      120 Dec 10 13:41 mannwhitneyu_pIC50.csv
# -rw-r--r-- 1 root root   125024 Dec 10 13:41 molecule.smi
# drwxrwxr-x 4 root root     4096 May 30  2020 PaDEL-Descriptor
# -rw-r--r-- 1 root root      231 Dec 10 11:38 padel.sh
# -rw-r--r-- 1 root root      231 Dec 10 12:28 padel.sh.1
# -rw-r--r-- 1 root root      231 Dec 10 12:29 padel.sh.2
# -rw-r--r-- 1 root root      231 Dec 10 13:35 padel.sh.3
# -rw-r--r-- 1 root root      231 Dec 10 13:41 padel.sh.4
# -rw-r--r-- 1 root root      231 Dec 10 13:41 padel.sh.5
# -rw-r--r-- 1 root root 25768637 Dec 10 11:38 padel.zip
# -rw-r--r-- 1 root root 25768637 Dec 10 12:28 padel.zip.1
# -rw-r--r-- 1 root root 25768637 Dec 10 12:29 padel.zip.2
# -rw-r--r-- 1 root root 25768637 Dec 10 13:35 padel.zip.3
# -rw-r--r-- 1 root root 25768637 Dec 10 13:41 padel.zip.4
# -rw-r--r-- 1 root root 25768637 Dec 10 13:41 padel.zip.5
# -rw-r--r-- 1 root root    13636 Dec 10 13:41 plot_bioactivity_class.pdf
# -rw-r--r-- 1 root root    15163 Dec 10 13:41 plot_ic50.pdf
# -rw-r--r-- 1 root root    12789 Dec 10 13:41 plot_LogP.pdf
# -rw-r--r-- 1 root root    12200 Dec 10 13:41 plot_MW.pdf
# -rw-r--r-- 1 root root    84441 Dec 10 13:41 plot_MW_vs_LogP.pdf
# -rw-r--r-- 1 root root    15117 Dec 10 13:41 plot_NumHAcceptors.pdf
# -rw-r--r-- 1 root root    15062 Dec 10 13:41 plot_NumHDonors.pdf
# -rw-r--r-- 1 root root   204234 Dec 10 12:28 results.zip
# drwxr-xr-x 1 root root     4096 Dec  3 14:33 sample_data

# %% [markdown]
# # Preparing the X and Y Data Matrices X data matrix

# %%
df3_X = pd.read_csv('descriptors_output.csv')

# %%
df3_X = df3_X.drop(columns=['Name'])
df3_X
# Out:
#      PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0             1           1  ...             0             0
# 1             1           1  ...             0             0
# 2             1           1  ...             0             0
# 3             1           1  ...             0             0
# 4             1           1  ...             0             0
# ..          ...         ...  ...           ...           ...
# 506           1           1  ...             0             0
# 507           1           1  ...             0             0
# 508           1           1  ...             0             0
# 509           1           1  ...             0             0
# 510           1           1  ...             0             0
#
# [511 rows x 881 columns]

# %% [markdown]
# **Y** variable
# Convert IC50 to pIC50

# %%
df3_Y = df3['pIC50']
df3_Y
# Out:
# 0     5.01
# 1     5.10
# 2     5.43
# 3     5.49
# 4     5.41
#       ...
# 506   4.52
# 507   4.52
# 508   4.52
# 509   4.52
# 510   4.52
# Name: pIC50, Length: 511, dtype: float64

# %% [markdown]
# Combining X and Y variable

# %%
dataset3 = pd.concat([df3_X,df3_Y], axis=1)
dataset3
# Out:
#      PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880  pIC50
# 0             1           1           1  ...             0             0   5.01
# 1             1           1           1  ...             0             0   5.10
# 2             1           1           1  ...             0             0   5.43
# 3             1           1           1  ...             0             0   5.49
# 4             1           1           1  ...             0             0   5.41
# ..          ...         ...         ...  ...           ...           ...    ...
# 506           1           1           0  ...             0             0   4.52
# 507           1           1           1  ...             0             0   4.52
# 508           1           1           1  ...             0             0   4.52
# 509           1           1           1  ...             0             0   4.52
# 510           1           1           1  ...             0             0   4.52
#
# [511 rows x 882 columns]

# %%
dataset3.to_csv('KV1.3_06_bioactivity_data_3class_pIC50_pubchem_fp.csv', index=False)

# %%
# ?input features Fingureprints
X = dataset3.drop('pIC50', axis=1)
X
# Out:
#      PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0             1           1  ...             0             0
# 1             1           1  ...             0             0
# 2             1           1  ...             0             0
# 3             1           1  ...             0             0
# 4             1           1  ...             0             0
# ..          ...         ...  ...           ...           ...
# 506           1           1  ...             0             0
# 507           1           1  ...             0             0
# 508           1           1  ...             0             0
# 509           1           1  ...             0             0
# 510           1           1  ...             0             0
#
# [511 rows x 881 columns]

# %%
# Out put
Y = dataset3.pIC50
Y
# Out:
# 0     5.01
# 1     5.10
# 2     5.43
# 3     5.49
# 4     5.41
#       ...
# 506   4.52
# 507   4.52
# 508   4.52
# 509   4.52
# 510   4.52
# Name: pIC50, Length: 511, dtype: float64

# %%
#  dimension
X.shape
# Out:
# (511, 881)

# %%
Y.shape
# Out:
# (511,)

# %% [markdown]
#  Remove **low** variance features

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)

# %%
X.shape
# Out:
# (511, 199)

# %% [markdown]
# Data split (80:20 )

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.2,random_state=2)

# %%
X_test.shape
# Out:
# (103, 199)

# %%
X_train.shape, Y_train.shape
# Out:
# ((408, 199), (408,))

# %% [markdown]
#  Building a Regression Model using Random Forest

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, Y_train)
r2 = model.score(X_test, Y_test)
r2
# Out:
# 0.9038294865542121

# %%
Y_pred = model.predict(X_test)

# %%
sns.set(color_codes=True)
sns.set_style("white")

ax = sns.regplot(Y_test, Y_pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize='large', fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize='large', fontweight='bold')
ax.set_xlim(0, 12)
ax.set_ylim(0, 12)
ax.figure.set_size_inches(5, 5)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# *Compare* ML algorithms

# %%
X_train.shape
# Out:
# (408, 199)

# %%
X_test.shape
# Out:
# (103, 199)

# %%
Y_train
# Out:
# 37    7.49
# 508   4.52
# 2     5.43
# 25    7.12
# 462   9.37
#       ...
# 22    6.51
# 72    6.49
# 493   4.52
# 15    6.33
# 168   5.13
# Name: pIC50, Length: 408, dtype: float64

# %%
# Defines and builds the lazyclassifier
clf1 = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
clf2 = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)

models_train,predictions_train = clf1.fit(X_train, X_train, Y_train, Y_train)

models_test,predictions_test = clf2.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████| 42/42 [00:15<00:00,  2.79it/s]
# 100%|██████████| 42/42 [00:14<00:00,  2.95it/s]

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                          Adjusted R-Squared  ...  Time Taken
# Model                                                        ...
# ExtraTreesRegressor                                    0.87  ...        0.74
# DecisionTreeRegressor                                  0.87  ...        0.08
# ExtraTreeRegressor                                     0.87  ...        0.05
# GaussianProcessRegressor                               0.87  ...        0.11
# XGBRegressor                                           0.87  ...        0.46
# RandomForestRegressor                                  0.84  ...        0.70
# BaggingRegressor                                       0.84  ...        0.12
# GradientBoostingRegressor                              0.81  ...        0.31
# LGBMRegressor                                          0.80  ...        0.12
# HistGradientBoostingRegressor                          0.80  ...        1.33
# LinearRegression                                       0.80  ...        0.06
# TransformedTargetRegressor                             0.80  ...        0.04
# Ridge                                                  0.79  ...        0.03
# HuberRegressor                                         0.76  ...        0.22
# RidgeCV                                                0.76  ...        0.06
# MLPRegressor                                           0.75  ...        0.73
# NuSVR                                                  0.75  ...        0.12
# LinearSVR                                              0.74  ...        0.25
# SVR                                                    0.74  ...        0.17
# PoissonRegressor                                       0.72  ...        0.05
# SGDRegressor                                           0.72  ...        0.04
# KNeighborsRegressor                                    0.72  ...        0.16
# BayesianRidge                                          0.71  ...        0.11
# OrthogonalMatchingPursuit                              0.70  ...        0.03
# LassoCV                                                0.69  ...        2.21
# ElasticNetCV                                           0.68  ...        3.06
# GammaRegressor                                         0.68  ...        0.05
# GeneralizedLinearRegressor                             0.68  ...        0.04
# TweedieRegressor                                       0.68  ...        0.09
# OrthogonalMatchingPursuitCV                            0.67  ...        0.06
# AdaBoostRegressor                                      0.65  ...        0.05
# LassoLarsIC                                            0.63  ...        0.05
# LassoLarsCV                                            0.62  ...        0.13
# LarsCV                                                 0.61  ...        1.14
# PassiveAggressiveRegressor                             0.57  ...        0.04
# ElasticNet                                             0.40  ...        0.03
# Lasso                                                 -0.06  ...        0.08
# DummyRegressor                                        -0.96  ...        0.03
# LassoLars                                             -0.96  ...        0.04
# KernelRidge                                          -27.66  ...        0.05
# Lars                                       -875600989564.92  ...        0.20
# RANSACRegressor               -5054644655464656234610688.00  ...        1.52
#
# [42 rows x 4 columns]

# %%
# Performance table of the test set (20% subset)
predictions_test[8:len(predictions_test)-1]
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# Lasso                                        1.57       0.46  1.43        0.09
# ElasticNet                                   1.31       0.71  1.05        0.03
# LinearSVR                                    1.24       0.77  0.92        0.23
# PassiveAggressiveRegressor                   1.19       0.82  0.83        0.04
# Ridge                                        1.19       0.82  0.83        0.03
# AdaBoostRegressor                            1.18       0.83  0.80        0.05
# LarsCV                                       1.17       0.84  0.79        1.00
# LassoLarsCV                                  1.17       0.84  0.78        0.12
# LassoLarsIC                                  1.16       0.85  0.75        0.05
# MLPRegressor                                 1.15       0.86  0.74        0.72
# HuberRegressor                               1.14       0.86  0.72        0.21
# OrthogonalMatchingPursuitCV                  1.14       0.87  0.71        0.06
# ExtraTreeRegressor                           1.14       0.87  0.70        0.04
# DecisionTreeRegressor                        1.14       0.87  0.70        0.04
# ExtraTreesRegressor                          1.13       0.87  0.69        0.73
# TweedieRegressor                             1.13       0.87  0.69        0.06
# GeneralizedLinearRegressor                   1.13       0.87  0.69        0.04
# GammaRegressor                               1.13       0.87  0.69        0.04
# ElasticNetCV                                 1.13       0.88  0.68        2.96
# LassoCV                                      1.13       0.88  0.68        2.16
# GradientBoostingRegressor                    1.12       0.88  0.66        0.30
# LGBMRegressor                                1.12       0.88  0.66        0.11
# HistGradientBoostingRegressor                1.12       0.88  0.66        1.32
# SGDRegressor                                 1.12       0.88  0.66        0.06
# BayesianRidge                                1.12       0.89  0.66        0.07
# NuSVR                                        1.12       0.89  0.66        0.10
# RidgeCV                                      1.12       0.89  0.65        0.05
# OrthogonalMatchingPursuit                    1.12       0.89  0.65        0.04
# PoissonRegressor                             1.12       0.89  0.64        0.05
# SVR                                          1.12       0.89  0.64        0.11
# KNeighborsRegressor                          1.11       0.89  0.64        0.10
# XGBRegressor                                 1.11       0.90  0.62        0.45
# RandomForestRegressor                        1.10       0.91  0.60        0.67

# %% [markdown]
# # Data visualization of model performance

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
